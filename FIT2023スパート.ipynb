# %% [markdown]
# ## 2023/08/10 23:01

# %%
import importlib
import os
import logging
from params import params
import params
importlib.reload(params)

#logging.basicConfig(encoding='utf-8', level=logging.DEBUG)
import rwkv_runner
importlib.reload(rwkv_runner)
from rwkv_runner import rwkv
importlib.reload(rwkv_runner)
from source_file_iterator import SourceFileIterator
import source_file_iterator
importlib.reload(source_file_iterator)

modelname = 'RWKV-4-Raven-3B-v11-Eng49%-Chn49%-Jpn1%-Other1%-20230429-ctx4096.pth'

os.environ["RWKV_CUDA_ON"] = '1'
r = rwkv(modelname,
         '20B_tokenizer.json',
         model_load=False)
# Out:
# <class 'tokenizers.Tokenizer'>
# tokenizer class= <class 'tokenizers.Tokenizer'>
# key_prefix= rwkv:RWKV-4-Raven-3B-v11-Eng49%-Chn49%-Jpn1%-Other1%-20230429-ctx4096.pth

# %% [markdown]
# ### こちらはPD類似度計算を検討するセクション

# %%
r.all_pd_plot()
# Out:
# data_subdirs= ['carroll', 'einstein', 'lovecraft']
# numTokensList= [1024]

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.CosSim
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= int

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# + sorted_emb = sorted_emb[:, indices]/100

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.Bottleneck
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - sorted_emb = sorted_emb[:, indices]/1000

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.Bottleneck
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %%
r.all_pd_plot()
# Out:
# data_subdirs= ['carroll', 'einstein', 'lovecraft']
# numTokensList= [1024]

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# ### こちらはraw+JFIPが異常なのを調査するセクション

# %%
import matplotlib.pyplot as plt
embFunc = r.getRwkvEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= Tensor

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中でnormalizeかました．topN=100

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中でnormalizeかました．topN=1000

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中でnormalizeかました．topN=10000

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - パラメータは上と同じ

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.CosSim
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= int

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中で/1000．topN=10000

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中でregularizeかました．topN=1000

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中でnormalizeかました．topN=20000

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %%
import matplotlib.pyplot as plt
embFunc = r.getPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %%
import matplotlib.pyplot as plt
embFunc = r.getPersistenceDiagramEmbeddings1d
simFunc = r.CosSim
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 8
#       6 ax = fig.add_subplot(1, 1, 1)
#       7 r.enable_simmat_cache = False
# ----> 8 matrix = r.simMat(embFunc, simFunc, numTokens)
#      10 r.simMatrixPlot(fig, ax, matrix)
#
# File /research/llmEmbeddingAnalysis/rwkv_runner.py:707, in rwkv.simMat(self, getEmbFunc, simFunc, numTokens)
#     705 if val is None or self.enable_simmat_cache is False:
#     706     logger.info(f"simMat cache not found")
# --> 707     simMat = self.getSimMatWithoutCache(getEmbFunc, simFunc, numTokens)
#     708     self.setDb(key, simMat)
#     709     val = simMat
#
# File /research/llmEmbeddingAnalysis/rwkv_runner.py:774, in rwkv.getSimMatWithoutCache(self, getEmbFunc, simFunc, numTokens)
#     772 rwkv_emb2 = self.__getEmbeddingsFromFD(out2, getEmbFunc)
#     773 #sim = self.getCosineSimilarity(rwkv_emb1, rwkv_emb2)
# ...

# %%
import matplotlib.pyplot as plt
embFunc = r.getRwkvEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= Tensor

# %%
import matplotlib.pyplot as plt
embFunc = r.getRwkvEmbeddings
simFunc = r.CosSim
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float

# %% [markdown]
# # 本日の成果

# %% [markdown]
# - PDをソートしてクロップしたあとにソートし直したり，正規化やスケーリングすることでボトルネック距離が結構いい感じに

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.Bottleneck
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - getHeadPersisitenceDiagramEmbeddingsの中でnormalizeかました．topN=10000．JFIPもかなりいい感じに

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float64

# %% [markdown]
# - CosSimは仕方がない？という結論が良い？

# %%
import matplotlib.pyplot as plt
embFunc = r.getHeadPersistenceDiagramEmbeddings
simFunc = r.CosSim
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= int

# %% [markdown]
# - raw＋JFIPはある程度仕方がない？

# %%
import matplotlib.pyplot as plt
embFunc = r.getRwkvEmbeddings
simFunc = r.JFIP
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= Tensor

# %% [markdown]
# - CosSimも？

# %%
import matplotlib.pyplot as plt
embFunc = r.getRwkvEmbeddings
simFunc = r.CosSim
numTokens = 1024
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
r.enable_simmat_cache = False
matrix = r.simMat(embFunc, simFunc, numTokens)

r.simMatrixPlot(fig, ax, matrix)
# Out:
# item= float
