# %%
import importlib
import os
import logging

#logging.basicConfig(encoding='utf-8', level=logging.DEBUG)
import rwkv_runner
importlib.reload(rwkv_runner)
from rwkv_runner import rwkv
importlib.reload(rwkv_runner)
from source_file_iterator import SourceFileIterator
import source_file_iterator
importlib.reload(source_file_iterator)
# Out:
# <module 'source_file_iterator' from '/research/llmEmbeddingAnalysis/source_file_iterator.py'>

# %%
rwkv
# Out:
# rwkv_runner.rwkv

# %%
modelname = 'RWKV-4-Raven-3B-v11-Eng49%-Chn49%-Jpn1%-Other1%-20230429-ctx4096.pth'

r = rwkv(modelname,
         '20B_tokenizer.json',
         model_load=False)
#r.getEmbeddingDataset()
# Out:
# INFO: 2023-07-16 01:53:41,310 - rwkv_runner.__init__ - initializing rwkv (rwkv_runner.py:84)
# key_prefix= rwkv:RWKV-4-Raven-3B-v11-Eng49%-Chn49%-Jpn1%-Other1%-20230429-ctx4096.pth

# %%
filename = './data/carroll/Through the Looking-Glass by Lewis Carroll'
fig = None
with open(filename, "r", encoding="utf-8") as f:
    ax = r.pd_plot(f, 1024)

# %%
r.getE

# %%
r.all_pd_plot()
# Out:
# INFO: 2023-07-08 01:44:02,065 - rwkv_runner.all_pd_plot - ((0, './data/carroll/Through the Looking-Glass by Lewis Carroll'), (0, 1024)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,069 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,070 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148030) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,091 - rwkv_runner.all_pd_plot - ((0, './data/carroll/Through the Looking-Glass by Lewis Carroll'), (1, 2048)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,094 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,095 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148737) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,113 - rwkv_runner.all_pd_plot - ((0, './data/carroll/Through the Looking-Glass by Lewis Carroll'), (2, 4096)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,116 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,117 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148178) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,135 - rwkv_runner.all_pd_plot - ((1, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll"), (0, 1024)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,138 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,139 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148979) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,157 - rwkv_runner.all_pd_plot - ((1, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll"), (1, 2048)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,160 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,161 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148001) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,181 - rwkv_runner.all_pd_plot - ((1, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll"), (2, 4096)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,184 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,185 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148581) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,203 - rwkv_runner.all_pd_plot - ((2, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll"), (0, 1024)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,207 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,207 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148670) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,226 - rwkv_runner.all_pd_plot - ((2, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll"), (1, 2048)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,229 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,229 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148504) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,248 - rwkv_runner.all_pd_plot - ((2, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll"), (2, 4096)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,251 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,251 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 148351) (rwkv_runner.py:246)
# INFO: 2023-07-08 01:44:02,271 - rwkv_runner.all_pd_plot - ((0, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski'), (0, 1024)) (rwkv_runner.py:314)
# DEBUG: 2023-07-08 01:44:02,274 - rwkv_runner.getPersistenceDiagramEmbeddings - PD embedding cache found (rwkv_runner.py:245)
# DEBUG: 2023-07-08 01:44:02,275 - rwkv_runner.getPersistenceDiagramEmbeddings - Persistence Diagram embedding shape=(2, 147802) (rwkv_runner.py:246)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 r.all_pd_plot()
#
# File /research/llmEmbeddingAnalysis/rwkv_runner.py:324, in rwkv.all_pd_plot(self)
#     321 numTokens = indexed_numTokens[1]
#     322 with open(file, "r", encoding="utf-8") as f:
#     323     #print("file=", file)
# --> 324     self.pd_subplot(fig, f, numTokens, max_rows, max_cols, count)
#     325 count += 1
#     326 out = next(iter, None)
#
# File /research/llmEmbeddingAnalysis/rwkv_runner.py:301, in rwkv.pd_subplot(self, fig, file, numTokens, row, column, seq)
#     299 if self.enable_pdemb_visualize is True:
#     300     pd_emb = self.getPersistenceDiagramEmbeddings(file, numTokens)
# --> 301     ax = fig.add_subplot(row, column, seq)
#     302     ax.scatter(pd_emb[0], pd_emb[1])
#     303     ax.set_title(textwrap.fill(f"file={file.name}, numTokens={numTokens}", 20), fontsize=8, wrap=True)
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# --> 757     ax = projection_class(self, *args, **pkw)
#     758     key = (projection_class, pkw)
#     759 return self._add_axes_internal(ax, key)
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/axes/_base.py:644, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     642 else:
#     643     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 644     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     645 if self._position.width < 0 or self._position.height < 0:
#     646     raise ValueError('Width and height specified must be non-negative')
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
#     597     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598         raise ValueError(
#     599             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600             f"not {num!r}"
#     601         )
#     602     i = j = num
#     603 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 9, not 10

# %%
simMatByCos= r.simMat(r.getRwkvEmbeddings, r.CosSim, 1024)
# Out:
# INFO: 2023-07-18 21:40:56,352 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=1024 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:CosSim:tokens=1024:simMat
# DEBUG: 2023-07-18 21:40:56,354 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)

# %%
simMatByCos.shape
# Out:
# (15, 15)

# %%
r.simMatrixPlot(simMatByCos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 r.simMatrixPlot(simMatByCos)
#
# TypeError: simMatrixPlot() missing 2 required positional arguments: 'ax' and 'matrix'

# %%
r.simMatrixPlot(r.getRwkvEmbeddings, r.CosSim, 1024)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 r.simMatrixPlot(r.getRwkvEmbeddings, r.CosSim, 1024)
#
# File /research/llmEmbeddingAnalysis/rwkv_runner.py:323, in simMatrixPlot(self, fig, ax, matrix)
#     321 elif type(f).__name__ == "list" or type(f).__name__ == "ndarray":
#     322     fip = np.dot(f.ravel(), g.ravel())
# --> 323 return fip
#
# AttributeError: 'function' object has no attribute 'invert_yaxis'

# %%
r.all_simMatrixPlot()
# Out:
# INFO: 2023-07-18 21:42:40,919 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=1024 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:CosSim:tokens=1024:simMat
# DEBUG: 2023-07-18 21:42:40,920 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:40,955 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=2048 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:CosSim:tokens=2048:simMat
# DEBUG: 2023-07-18 21:42:40,956 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:40,993 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=4096 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:CosSim:tokens=4096:simMat
# DEBUG: 2023-07-18 21:42:40,993 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,025 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=JFIP, tokens=1024 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:JFIP:tokens=1024:simMat
# DEBUG: 2023-07-18 21:42:41,026 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,063 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=JFIP, tokens=2048 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:JFIP:tokens=2048:simMat
# DEBUG: 2023-07-18 21:42:41,065 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,096 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=JFIP, tokens=4096 (rwkv_runner.py:431)
# key= getRwkvEmbeddings:JFIP:tokens=4096:simMat
# DEBUG: 2023-07-18 21:42:41,097 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,131 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=CosSim, tokens=1024 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:CosSim:tokens=1024:simMat
# DEBUG: 2023-07-18 21:42:41,131 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,164 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=CosSim, tokens=2048 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:CosSim:tokens=2048:simMat
# DEBUG: 2023-07-18 21:42:41,165 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,197 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=CosSim, tokens=4096 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:CosSim:tokens=4096:simMat
# DEBUG: 2023-07-18 21:42:41,198 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,230 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=JFIP, tokens=1024 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:JFIP:tokens=1024:simMat
# DEBUG: 2023-07-18 21:42:41,231 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,268 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=JFIP, tokens=2048 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:JFIP:tokens=2048:simMat
# DEBUG: 2023-07-18 21:42:41,269 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,303 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=JFIP, tokens=4096 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:JFIP:tokens=4096:simMat
# DEBUG: 2023-07-18 21:42:41,304 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,340 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=Bottleneck, tokens=1024 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:Bottleneck:tokens=1024:simMat
# DEBUG: 2023-07-18 21:42:41,341 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,374 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=Bottleneck, tokens=2048 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:Bottleneck:tokens=2048:simMat
# DEBUG: 2023-07-18 21:42:41,375 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
# INFO: 2023-07-18 21:42:41,636 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=Bottleneck, tokens=4096 (rwkv_runner.py:431)
# key= getHeadPersistenceDiagramEmbeddings:Bottleneck:tokens=4096:simMat
# DEBUG: 2023-07-18 21:42:41,637 - rwkv_runner.simMat - simMat cache found (rwkv_runner.py:443)
