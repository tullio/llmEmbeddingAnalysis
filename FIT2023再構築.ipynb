# %%
import importlib
import os
import logging

#logging.basicConfig(encoding='utf-8', level=logging.DEBUG)
import rwkv_runner
importlib.reload(rwkv_runner)
from rwkv_runner import rwkv
importlib.reload(rwkv_runner)
from source_file_iterator import SourceFileIterator
import source_file_iterator
importlib.reload(source_file_iterator)
# Out:
# <module 'source_file_iterator' from '/research/llmEmbeddingAnalysis/source_file_iterator.py'>

# %%
rwkv
# Out:
# rwkv_runner.rwkv

# %%
modelname = 'RWKV-4-Raven-3B-v11-Eng49%-Chn49%-Jpn1%-Other1%-20230429-ctx4096.pth'

os.environ["RWKV_CUDA_ON"] = '1'
r = rwkv(modelname,
         '20B_tokenizer.json',
         model_load=False)
#r.getEmbeddingDataset()
# Out:
# INFO: 2023-08-05 22:54:27,300 - rwkv_runner.__init__ - initializing rwkv (rwkv_runner.py:94)
# <class 'tokenizers.Tokenizer'>
# tokenizer class= <class 'tokenizers.Tokenizer'>
# key_prefix= rwkv:RWKV-4-Raven-3B-v11-Eng49%-Chn49%-Jpn1%-Other1%-20230429-ctx4096.pth

# %%
filename = './data/carroll/Through the Looking-Glass by Lewis Carroll'
fig = None
with open(filename, "r", encoding="utf-8") as f:
    ax = r.pd_plot(f, 1024)

# %%
r.getE

# %%
r.all_pd_plot()
# Out:
# data_subdirs= ['carroll', 'einstein', 'lovecraft']
# numTokensList= [1024, 2048, 4096]
# (0, './data/carroll/Through the Looking-Glass by Lewis Carroll')
# (0, './data/carroll/Through the Looking-Glass by Lewis Carroll')
# (0, './data/carroll/Through the Looking-Glass by Lewis Carroll')
# (1, './data/carroll/The Hunting of the Snark: An Agony in Eight Fits by Lewis Carroll')
# (1, './data/carroll/The Hunting of the Snark: An Agony in Eight Fits by Lewis Carroll')
# (1, './data/carroll/The Hunting of the Snark: An Agony in Eight Fits by Lewis Carroll')
# (2, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll")
# (2, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll")
# (2, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll")
# (3, './data/carroll/Sylvie and Bruno by Lewis Carroll')
# (3, './data/carroll/Sylvie and Bruno by Lewis Carroll')
# (3, './data/carroll/Sylvie and Bruno by Lewis Carroll')
# (4, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll")
# (4, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll")
# (4, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll")
# (0, './data/einstein/The Meaning of Relativity by Albert Einstein')
# (0, './data/einstein/The Meaning of Relativity by Albert Einstein')
# (0, './data/einstein/The Meaning of Relativity by Albert Einstein')
# (1, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski')
# (1, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski')
# (1, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski')
# (2, './data/einstein/The A B C of Relativity by Bertrand Russell')
# (2, './data/einstein/The A B C of Relativity by Bertrand Russell')
# (2, './data/einstein/The A B C of Relativity by Bertrand Russell')
# (3, './data/einstein/Relativity: The Special and General Theory by Albert Einstein')
# (3, './data/einstein/Relativity: The Special and General Theory by Albert Einstein')
# (3, './data/einstein/Relativity: The Special and General Theory by Albert Einstein')
# (4, "./data/einstein/The foundations of Einstein's theory of gravitation by Erwin Freundlicha")
# (4, "./data/einstein/The foundations of Einstein's theory of gravitation by Erwin Freundlicha")
# (4, "./data/einstein/The foundations of Einstein's theory of gravitation by Erwin Freundlicha")
# (0, "./data/lovecraft/Medusa's coil by Zealia B. Bishop and H. P. Lovecraft")
# (0, "./data/lovecraft/Medusa's coil by Zealia B. Bishop and H. P. Lovecraft")
# (0, "./data/lovecraft/Medusa's coil by Zealia B. Bishop and H. P. Lovecraft")
# (1, './data/lovecraft/At the mountains of madness by H. P. Lovecraft')
# (1, './data/lovecraft/At the mountains of madness by H. P. Lovecraft')
# (1, './data/lovecraft/At the mountains of madness by H. P. Lovecraft')
# (2, './data/lovecraft/The curse of Yig by Zealia B. Bishop and H. P. Lovecraft')
# (2, './data/lovecraft/The curse of Yig by Zealia B. Bishop and H. P. Lovecraft')
# (2, './data/lovecraft/The curse of Yig by Zealia B. Bishop and H. P. Lovecraft')
# (3, './data/lovecraft/The call of Cthulhu by H. P. Lovecraft')
# (3, './data/lovecraft/The call of Cthulhu by H. P. Lovecraft')
# (3, './data/lovecraft/The call of Cthulhu by H. P. Lovecraft')
# (4, './data/lovecraft/The Dunwich Horror by H. P. Lovecraft')
# (4, './data/lovecraft/The Dunwich Horror by H. P. Lovecraft')
# (4, './data/lovecraft/The Dunwich Horror by H. P. Lovecraft')
# count= 15
# INFO: 2023-08-05 22:54:31,083 - rwkv_runner.all_pd_plot - ((0, './data/carroll/Through the Looking-Glass by Lewis Carroll'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,108 - rwkv_runner.all_pd_plot - ((0, './data/carroll/Through the Looking-Glass by Lewis Carroll'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,133 - rwkv_runner.all_pd_plot - ((0, './data/carroll/Through the Looking-Glass by Lewis Carroll'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,160 - rwkv_runner.all_pd_plot - ((1, './data/carroll/The Hunting of the Snark: An Agony in Eight Fits by Lewis Carroll'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,184 - rwkv_runner.all_pd_plot - ((1, './data/carroll/The Hunting of the Snark: An Agony in Eight Fits by Lewis Carroll'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,210 - rwkv_runner.all_pd_plot - ((1, './data/carroll/The Hunting of the Snark: An Agony in Eight Fits by Lewis Carroll'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,236 - rwkv_runner.all_pd_plot - ((2, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll"), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,261 - rwkv_runner.all_pd_plot - ((2, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll"), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,286 - rwkv_runner.all_pd_plot - ((2, "./data/carroll/Alice's Adventures in Wonderland by Lewis Carroll"), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,311 - rwkv_runner.all_pd_plot - ((3, './data/carroll/Sylvie and Bruno by Lewis Carroll'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,338 - rwkv_runner.all_pd_plot - ((3, './data/carroll/Sylvie and Bruno by Lewis Carroll'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,363 - rwkv_runner.all_pd_plot - ((3, './data/carroll/Sylvie and Bruno by Lewis Carroll'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,388 - rwkv_runner.all_pd_plot - ((4, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll"), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,415 - rwkv_runner.all_pd_plot - ((4, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll"), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,440 - rwkv_runner.all_pd_plot - ((4, "./data/carroll/Alice's Adventures Under Ground by Lewis Carroll"), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,465 - rwkv_runner.all_pd_plot - ((0, './data/einstein/The Meaning of Relativity by Albert Einstein'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,489 - rwkv_runner.all_pd_plot - ((0, './data/einstein/The Meaning of Relativity by Albert Einstein'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,515 - rwkv_runner.all_pd_plot - ((0, './data/einstein/The Meaning of Relativity by Albert Einstein'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,541 - rwkv_runner.all_pd_plot - ((1, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,566 - rwkv_runner.all_pd_plot - ((1, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,591 - rwkv_runner.all_pd_plot - ((1, './data/einstein/The Principle of Relativity by Albert Einstein and H. Minkowski'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,617 - rwkv_runner.all_pd_plot - ((2, './data/einstein/The A B C of Relativity by Bertrand Russell'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,642 - rwkv_runner.all_pd_plot - ((2, './data/einstein/The A B C of Relativity by Bertrand Russell'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,666 - rwkv_runner.all_pd_plot - ((2, './data/einstein/The A B C of Relativity by Bertrand Russell'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,691 - rwkv_runner.all_pd_plot - ((3, './data/einstein/Relativity: The Special and General Theory by Albert Einstein'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,717 - rwkv_runner.all_pd_plot - ((3, './data/einstein/Relativity: The Special and General Theory by Albert Einstein'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,742 - rwkv_runner.all_pd_plot - ((3, './data/einstein/Relativity: The Special and General Theory by Albert Einstein'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,767 - rwkv_runner.all_pd_plot - ((4, "./data/einstein/The foundations of Einstein's theory of gravitation by Erwin Freundlicha"), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,793 - rwkv_runner.all_pd_plot - ((4, "./data/einstein/The foundations of Einstein's theory of gravitation by Erwin Freundlicha"), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,817 - rwkv_runner.all_pd_plot - ((4, "./data/einstein/The foundations of Einstein's theory of gravitation by Erwin Freundlicha"), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,841 - rwkv_runner.all_pd_plot - ((0, "./data/lovecraft/Medusa's coil by Zealia B. Bishop and H. P. Lovecraft"), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,866 - rwkv_runner.all_pd_plot - ((0, "./data/lovecraft/Medusa's coil by Zealia B. Bishop and H. P. Lovecraft"), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,893 - rwkv_runner.all_pd_plot - ((0, "./data/lovecraft/Medusa's coil by Zealia B. Bishop and H. P. Lovecraft"), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,918 - rwkv_runner.all_pd_plot - ((1, './data/lovecraft/At the mountains of madness by H. P. Lovecraft'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,943 - rwkv_runner.all_pd_plot - ((1, './data/lovecraft/At the mountains of madness by H. P. Lovecraft'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,968 - rwkv_runner.all_pd_plot - ((1, './data/lovecraft/At the mountains of madness by H. P. Lovecraft'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:31,995 - rwkv_runner.all_pd_plot - ((2, './data/lovecraft/The curse of Yig by Zealia B. Bishop and H. P. Lovecraft'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,020 - rwkv_runner.all_pd_plot - ((2, './data/lovecraft/The curse of Yig by Zealia B. Bishop and H. P. Lovecraft'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,045 - rwkv_runner.all_pd_plot - ((2, './data/lovecraft/The curse of Yig by Zealia B. Bishop and H. P. Lovecraft'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,070 - rwkv_runner.all_pd_plot - ((3, './data/lovecraft/The call of Cthulhu by H. P. Lovecraft'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,096 - rwkv_runner.all_pd_plot - ((3, './data/lovecraft/The call of Cthulhu by H. P. Lovecraft'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,120 - rwkv_runner.all_pd_plot - ((3, './data/lovecraft/The call of Cthulhu by H. P. Lovecraft'), (2, 4096)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,145 - rwkv_runner.all_pd_plot - ((4, './data/lovecraft/The Dunwich Horror by H. P. Lovecraft'), (0, 1024)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,174 - rwkv_runner.all_pd_plot - ((4, './data/lovecraft/The Dunwich Horror by H. P. Lovecraft'), (1, 2048)) (rwkv_runner.py:568)
# INFO: 2023-08-05 22:54:32,199 - rwkv_runner.all_pd_plot - ((4, './data/lovecraft/The Dunwich Horror by H. P. Lovecraft'), (2, 4096)) (rwkv_runner.py:568)

# %%
simMatByCos= r.simMat(r.getRwkvEmbeddings, r.CosSim, 1024)
# Out:
# INFO: 2023-07-27 18:21:18,398 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=1024 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:CosSim:tokens=1024:simMat

# %%
simMatByCos.shape
# Out:
# (15, 15)

# %%
r.simMatrixPlot(simMatByCos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 r.simMatrixPlot(simMatByCos)
#
# TypeError: simMatrixPlot() missing 2 required positional arguments: 'ax' and 'matrix'

# %%
r.simMatrixPlot(r.getRwkvEmbeddings, r.CosSim, 1024)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 r.simMatrixPlot(r.getRwkvEmbeddings, r.CosSim, 1024)
#
# File /research/llmEmbeddingAnalysis/rwkv_runner.py:323, in simMatrixPlot(self, fig, ax, matrix)
#     321 elif type(f).__name__ == "list" or type(f).__name__ == "ndarray":
#     322     fip = np.dot(f.ravel(), g.ravel())
# --> 323 return fip
#
# AttributeError: 'function' object has no attribute 'invert_yaxis'

# %%
r.all_simMatrixPlot()
# Out:
# INFO: 2023-07-27 18:21:27,176 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=1024 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:CosSim:tokens=1024:simMat
# INFO: 2023-07-27 18:21:27,219 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=2048 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:CosSim:tokens=2048:simMat
# INFO: 2023-07-27 18:21:27,255 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=CosSim, tokens=4096 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:CosSim:tokens=4096:simMat
# INFO: 2023-07-27 18:21:27,292 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=JFIP, tokens=1024 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:JFIP:tokens=1024:simMat
# INFO: 2023-07-27 18:21:27,327 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=JFIP, tokens=2048 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:JFIP:tokens=2048:simMat
# INFO: 2023-07-27 18:21:27,503 - rwkv_runner.simMat - embedding=getRwkvEmbeddings,similarity=JFIP, tokens=4096 (rwkv_runner.py:503)
# key= getRwkvEmbeddings:JFIP:tokens=4096:simMat
# INFO: 2023-07-27 18:21:27,540 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=CosSim, tokens=1024 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:CosSim:tokens=1024:simMat
# INFO: 2023-07-27 18:21:27,577 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=CosSim, tokens=2048 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:CosSim:tokens=2048:simMat
# INFO: 2023-07-27 18:21:27,614 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=CosSim, tokens=4096 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:CosSim:tokens=4096:simMat
# INFO: 2023-07-27 18:21:27,651 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=JFIP, tokens=1024 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:JFIP:tokens=1024:simMat
# INFO: 2023-07-27 18:21:27,688 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=JFIP, tokens=2048 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:JFIP:tokens=2048:simMat
# INFO: 2023-07-27 18:21:27,725 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=JFIP, tokens=4096 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:JFIP:tokens=4096:simMat
# INFO: 2023-07-27 18:21:27,763 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=Bottleneck, tokens=1024 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:Bottleneck:tokens=1024:simMat
# INFO: 2023-07-27 18:21:27,800 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=Bottleneck, tokens=2048 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:Bottleneck:tokens=2048:simMat
# INFO: 2023-07-27 18:21:27,839 - rwkv_runner.simMat - embedding=getHeadPersistenceDiagramEmbeddings,similarity=Bottleneck, tokens=4096 (rwkv_runner.py:503)
# key= getHeadPersistenceDiagramEmbeddings:Bottleneck:tokens=4096:simMat
